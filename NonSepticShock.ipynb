# %%
import pandas as pd
import plotly.express as px

dataset=pd.read_csv('Dataset1.csv')
dataset.head(10)
# Out:
#    Unnamed: 0  Hour    HR  O2Sat   Temp    SBP   MAP   DBP  Resp  EtCO2  ...  \
# 0           0     0   NaN    NaN    NaN    NaN   NaN   NaN   NaN    NaN  ...
# 1           1     1  65.0  100.0    NaN    NaN  72.0   NaN  16.5    NaN  ...
# 2           2     2  78.0  100.0    NaN    NaN  42.5   NaN   NaN    NaN  ...
# 3           3     3  73.0  100.0    NaN    NaN   NaN   NaN  17.0    NaN  ...
# 4           4     4  70.0  100.0    NaN  129.0  74.0  69.0  14.0    NaN  ...
# 5           5     5  62.0  100.0    NaN  124.0  85.0  61.0  14.0    NaN  ...
# 6           6     6  61.0  100.0    NaN  101.0  75.0  58.0  14.0    NaN  ...
# 7           7     7  68.0  100.0  35.78  142.0  93.5  78.0  16.0    NaN  ...
# 8           8     8  71.0  100.0    NaN  121.0  74.0  91.0  14.0    NaN  ...
# 9           9     9  69.0  100.0    NaN  120.0  79.0  98.0  14.0    NaN  ...
#
#    Fibrinogen  Platelets    Age  Gender  Unit1  Unit2  HospAdmTime  ICULOS  \
# ...

# %%
septic_id=[]
test=1
for row in dataset.itertuples():
    if test !=row.Patient_ID:
        if row.SepsisLabel == 1:
            test=row.Patient_ID
            septic_id.append(row.Patient_ID)
            
number_of_elements_septic = len(septic_id)

print("Total number of unique Patient IDs: ", number_of_elements_septic)
# Out:
# Total number of unique Patient IDs:  2932

# %%
full_id=[]

test2=1
for row in dataset.itertuples():
    if test2 !=row.Patient_ID:
        test2=row.Patient_ID
        full_id.append(row.Patient_ID)

    
# print(full_id)

number_of_elements_full = len(full_id)

print("Total number of unique Patient IDs: ", number_of_elements_full)
# Out:
# Total number of unique Patient IDs:  40336

# %%
non_septic_id = list(set(full_id) - set(septic_id))

number_of_elements_nonseptic = len(non_septic_id)


print("Total number of unique non-septic Patient IDs: ", number_of_elements_nonseptic)
# Out:
# Total number of unique non-septic Patient IDs:  37404

# %%
# Data for patients that did not go into septic shock

import pandas as pd

data = pd.read_csv('Dataset1.csv')

for i,value in enumerate(non_septic_id):
    data[data['Patient_ID'] == value].to_csv(r'Patient_ID_'+str(value)+r'.csv',index = False, na_rep = 'N/A')
