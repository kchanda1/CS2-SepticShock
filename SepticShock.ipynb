# %%
import pandas as pd
import plotly.express as px

dataset=pd.read_csv('Dataset1.csv')
dataset.head(10)
# Out:
#    Unnamed: 0  Hour    HR  O2Sat   Temp    SBP   MAP   DBP  Resp  EtCO2  ...  \
# 0           0     0   NaN    NaN    NaN    NaN   NaN   NaN   NaN    NaN  ...
# 1           1     1  65.0  100.0    NaN    NaN  72.0   NaN  16.5    NaN  ...
# 2           2     2  78.0  100.0    NaN    NaN  42.5   NaN   NaN    NaN  ...
# 3           3     3  73.0  100.0    NaN    NaN   NaN   NaN  17.0    NaN  ...
# 4           4     4  70.0  100.0    NaN  129.0  74.0  69.0  14.0    NaN  ...
# 5           5     5  62.0  100.0    NaN  124.0  85.0  61.0  14.0    NaN  ...
# 6           6     6  61.0  100.0    NaN  101.0  75.0  58.0  14.0    NaN  ...
# 7           7     7  68.0  100.0  35.78  142.0  93.5  78.0  16.0    NaN  ...
# 8           8     8  71.0  100.0    NaN  121.0  74.0  91.0  14.0    NaN  ...
# 9           9     9  69.0  100.0    NaN  120.0  79.0  98.0  14.0    NaN  ...
#
#    Fibrinogen  Platelets    Age  Gender  Unit1  Unit2  HospAdmTime  ICULOS  \
# ...

# %%
df = dataset[dataset['SepsisLabel'] >0]
print(df.nunique())
# counts = df.nunique('Patient_ID')
# print(counts)
# Out:
# Unnamed: 0           336
# Hour                 336
# HR                   249
# O2Sat                 71
# Temp                 290
# SBP                  424
# MAP                  490
# DBP                  226
# Resp                 142
# EtCO2                 94
# BaseExcess           143
# HCO3                  92
# FiO2                  50
# pH                    70
# PaCO2                197
# SaO2                 225
# AST                  287
# BUN                  132
# Alkalinephos         234
# Calcium              203
# Chloride              53
# Creatinine           406
# Bilirubin_direct      58
# Glucose              465
# Lactate              450
# Magnesium             35
# Phosphate             97
# Potassium            154
# Bilirubin_total      133
# TroponinI            155
# Hct                  304
# Hgb                  145
# PTT                  461
# WBC                  336
# Fibrinogen           222
# Platelets            462
# Age                 1571
# ...

# %%
# Septic Shock Patien_ID ----MULTIPLE
septic_id=[]
for row in dataset.itertuples():
    if row.SepsisLabel == 1:
        septic_id.append(row.Patient_ID)
    
print(septic_id)
# Out:
# [11093, 11093, 11093, 11093, 11093, 11093, 11093, 11093, 11093, 11093, 10355, 10355, 10355, 10355, 10355, 10355, 10355, 10355, 10355, 10355, 5328, 5328, 5328, 5328, 5328, 5328, 5328, 5328, 5328, 5092, 5092, 5092, 5092, 5092, 5092, 5092, 5092, 5092, 5092, 19826, 19826, 19826, 19826, 19826, 19826, 19826, 19826, 19826, 654, 654, 654, 654, 654, 654, 654, 654, 654, 654, 20354, 20354, 20354, 20354, 20354, 20354, 20354, 20354, 20354, 20354, 5462, 5462, 5462, 5462, 5462, 5462, 5462, 5462, 5462, 5462, 11187, 11187, 11187, 11187, 11187, 11187, 11187, 11187, 11187, 15445, 15445, 15445, 15445, 15445, 15445, 15445, 15445, 15445, 15445, 7423, 7423, 7423, 7423, 7423, 7423, 7423, 7423, 7423, 7423, 6499, 6499, 6499, 6499, 6499, 6499, 6499, 6499, 6499, 14037, 14037, 14037, 14037, 14037, 14037, 14037, 14037, 14037, 12682, 12682, 12682, 12682, 12682, 12682, 12682, 12682, 12682, 12682, 7911, 7911, 7911, 7911, 7911, 7911, 7911, 7911, 18305, 18305, 18305, 18305, 18305, 18305, 18305, 18305, 18305, 18305, 63
# ...

# %%
for row in dataset.itertuples():
    if row.SepsisLabel == 1:
        print(row.Patient_ID)
# Out:
# 11093
# 11093
# 11093
# 11093
# 11093
# 11093
# 11093
# 11093
# 11093
# 11093
# 10355
# 10355
# 10355
# 10355
# 10355
# 10355
# 10355
# 10355
# 10355
# 10355
# 5328
# 5328
# 5328
# 5328
# 5328
# 5328
# 5328
# 5328
# 5328
# 5092
# 5092
# 5092
# 5092
# 5092
# 5092
# 5092
# 5092
# 5092
# 5092
# 19826
# 19826
# 19826
# 19826
# 19826
# 19826
# 19826
# 19826
# 19826
# 654
# 654
# 654
# 654
# 654
# 654
# 654
# 654
# 654
# 654
# 20354
# 20354
# 20354
# 20354
# 20354
# 20354
# 20354
# 20354
# 20354
# 20354
# 5462
# 5462
# 5462
# 5462
# 5462
# 5462
# 5462
# 5462
# 5462
# 5462
# 11187
# 11187
# 11187
# 11187
# 11187
# 11187
# 11187
# 11187
# 11187
# 15445
# 15445
# 15445
# 15445
# 15445
# 15445
# 15445
# 15445
# 15445
# 15445
# 7423
# 7423
# 7423
# 7423
# 7423
# 7423
# 7423
# 7423
# 7423
# 7423
# 6499
# 6499
# 6499
# 6499
# 6499
# 6499
# 6499
# 6499
# 6499
# 14037
# 14037
# 14037
# 14037
# 14037
# 14037
# 14037
# 14037
# 14037
# 12682
# 12682
# 12682
# 12682
# 12682
# 12682
# 12682
# 12682
# ...

# %%
# Septic SHock Patient_ID UNIQUE VALUES IN LIST
septic_id=[]
test=1
for row in dataset.itertuples():
    if test !=row.Patient_ID:
        if row.SepsisLabel == 1:
            test=row.Patient_ID
            septic_id.append(row.Patient_ID)

    
print(septic_id)
# Out:
# [11093, 10355, 5328, 5092, 19826, 654, 20354, 5462, 11187, 15445, 7423, 6499, 14037, 12682, 7911, 18305, 6351, 1441, 4487, 1849, 10209, 10115, 4939, 11444, 11551, 17690, 7837, 14888, 13492, 10497, 13830, 7870, 19210, 17931, 2213, 19010, 13149, 19510, 7987, 1092, 13812, 16220, 5981, 18369, 11967, 17052, 728, 3791, 7280, 7001, 851, 13946, 13204, 18278, 11575, 20563, 14545, 11772, 15476, 10756, 11454, 12784, 18053, 11745, 20554, 3247, 6260, 1072, 11, 1811, 22, 15094, 14597, 8654, 19007, 18440, 18736, 15619, 10490, 5053, 8772, 18507, 9894, 311, 3778, 9962, 10888, 8332, 4868, 5317, 272, 18650, 7649, 17048, 10645, 14774, 16427, 19675, 3377, 14409, 19153, 1307, 3018, 15571, 7070, 2659, 11319, 3650, 16343, 4368, 17638, 12278, 2853, 784, 10289, 5519, 19421, 972, 12525, 2927, 18575, 5748, 6632, 14251, 19738, 1370, 8684, 11056, 11565, 19492, 14046, 17043, 17644, 5765, 6321, 12562, 9435, 4865, 18930, 5427, 15057, 9129, 4824, 9921, 6785, 5719, 11899, 10549, 9591, 17754, 9862, 13623, 18556, 6496, 
# ...

# %%
number_of_elements = len(septic_id)

print("Number of elements in the list: ", number_of_elements)
# Out:
# Number of elements in the list:  2932

# %%
# Data for patients that went into septic shock

import pandas as pd

data = pd.read_csv('Dataset1.csv')

#     data_category_range = data['Category'].unique()
#     data_category_range = data_category_range.tolist()

for i,value in enumerate(septic_id):
#     value.to_csv(f'{SepticShock}.csv', index=False)
    data[data['Patient_ID'] == value].to_csv(r'Patient_ID_'+str(value)+r'.csv',index = False, na_rep = 'N/A')

# %%
# Data for patients who didnt go into septic shock

import pandas as pd

data = pd.read_csv('Dataset1.csv')

#     data_category_range = data['Category'].unique()
#     data_category_range = data_category_range.tolist()

for i,value in enumerate(septic_id):
#     value.to_csv(f'{SepticShock}.csv', index=False)
    data[data['Patient_ID'] != value].to_csv(r'Patient_ID_'+str(value)+r'.csv',index = False, na_rep = 'N/A')
